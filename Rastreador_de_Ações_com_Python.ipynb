# %% [markdown]
# <a href="https://colab.research.google.com/github/taizaoliveira/Rastreador_de_Acoes_com_Python/blob/main/Rastreador_de_A%C3%A7%C3%B5es_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação das Bibliotecas

# %%
# !pip install yfinance
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Definindo as ações

# %%
acoes = ['AAPL', 'MSFT', 'PETR4.SA', 'BBDC4.SA']

# %% [markdown]
# # Importando os dados

# %%
dados_acoes = yf.download(acoes, period='1d', start='2023-01-01')
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %% [markdown]
# # Primeiro Gráfico

# %%
dados_acoes['Close'].plot()
plt.xlabel('Data')
plt.ylabel('Preço de fechamento')
plt.title('Rastreador de Ações')
plt.legend(acoes, fontsize=7)
plt.show()

# %% [markdown]
# # Normalizando os preços

# %%
dados_normalizados = dados_acoes['Close'] / dados_acoes['Close'].iloc[0]
dados_normalizados.plot()
plt.xlabel('Data')
plt.ylabel('Preço normalizado')
plt.title('Rastreador de Ações')
plt.legend(acoes, fontsize=7)
plt.show()
